# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SayyadAmmu'

# %%
code

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'Credit_Score.csv'
df = pd.read_csv(file_path)

# %%
# Display basic information about the dataset
print("Basic Information:")
print(df.info())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13744 entries, 0 to 13743
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      13744 non-null  object
#  1   CustomerID              13744 non-null  object
#  2   Month                   13744 non-null  object
#  3   Name                    13744 non-null  object
#  4   Age                     13744 non-null  int64
#  5   SSN                     13744 non-null  object
#  6   Occupation              13744 non-null  object
#  7   AnnualIncome            13744 non-null  float64
#  8   MonthlyInhandSalary     13744 non-null  float64
#  9   NumBankAccounts         13744 non-null  int64
#  10  NumCreditCard           13744 non-null  int64
#  11  InterestRate            13744 non-null  int64
#  12  NumofLoan               13744 non-null  int64
#  13  TypeofLoan              13744 non-null  object
#  14  Delayfromduedate        13744 non-null  int64
#  15  NumofDelayedPayment     13744 non-null  int64
#  16  ChangedCreditLimit      13744 non-null  float64
#  17  NumCreditInquiries      13744 non-null  int64
#  18  CreditMix               13744 non-null  object
#  19  OutstandingDebt         13744 non-null  float64
#  20  CreditUtilizationRatio  13744 non-null  float64
#  21  CreditHistoryAge        13744 non-null  object
#  22  PaymentofMinAmount      13744 non-null  object
#  23  TotalEMIpermonth        13744 non-null  float64
#  24  Amountinvestedmonthly   13744 non-null  float64
#  25  PaymentBehaviour        13744 non-null  object
#  26  MonthlyBalance          13744 non-null  float64
# dtypes: float64(8), int64(8), object(11)
# memory usage: 2.8+ MB
# None

# %%
# Display the first few rows of the dataset
print("\nFirst Few Rows:")
print(df.head())
# Out:
# First Few Rows:
#        ID CustomerID      Month           Name  Age          SSN  \
# 0  0x160b   CUS0xd40    October  Aaron Maashoh   24  821-00-0265
# 1  0x1623  CUS0x2dbc    October         Langep   35  486-85-3974
# 2  0x162e  CUS0xb891  September         Jasond   55  072-31-6145
# 3  0x1630  CUS0xb891   November         Jasond   55  072-31-6145
# 4  0x1631  CUS0xb891   December         Jasond   55  072-31-6145
#
#      Occupation  AnnualIncome  MonthlyInhandSalary  NumBankAccounts  ...  \
# 0     Scientist      19114.12          1824.843333                3  ...
# 1      Engineer     143162.64         12187.220000                1  ...
# 2  Entrepreneur      30689.89          2612.490833                2  ...
# 3  Entrepreneur      30689.89          2612.490833                2  ...
# 4  Entrepreneur    4148862.00          2612.490833                2  ...
#
#    NumCreditInquiries  CreditMix  OutstandingDebt CreditUtilizationRatio  \
# 0                   4       Good           809.98              33.053114
# 1                   3       Good          1303.01              35.685836
# 2                   4       Good           632.46              39.377219
# 3                   4       Good           632.46              36.824468
# 4                   7       Good           632.46              35.579265
#
#          CreditHistoryAge  PaymentofMinAmount  TotalEMIpermonth  \
# 0  22 Years and 10 Months                  No         49.574949
# 1   18 Years and 6 Months                  No        246.992320
# 2  17 Years and 11 Months                  No         16.415452
# 3   18 Years and 1 Months                  No         16.415452
# 4   18 Years and 2 Months                  No         16.415452
#
#    Amountinvestedmonthly              PaymentBehaviour  MonthlyBalance
# 0              21.465380  HighspentMediumvaluepayments      361.444004
# 1             453.615131    LowspentLargevaluepayments      788.114550
# 2              69.107006  HighspentMediumvaluepayments      425.726626
# 3             191.886244   LowspentMediumvaluepayments      332.947388
# 4             233.933417    LowspentSmallvaluepayments      300.900215
#
# [5 rows x 27 columns]

# %%
# Display summary statistics for numerical columns
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#                 Age  AnnualIncome  MonthlyInhandSalary  NumBankAccounts  \
# count  13744.000000  1.374400e+04         13744.000000     13744.000000
# mean      33.321959  1.548992e+05          3979.448901         5.592622
# std       10.632785  1.293621e+06          3068.495677         2.580778
# min       14.000000  7.005930e+03           303.645417         0.000000
# 25%       25.000000  1.850807e+04          1548.303334         4.000000
# 50%       33.000000  3.595245e+04          2979.444167         6.000000
# 75%       42.000000  6.934711e+04          5631.933333         8.000000
# max       95.000000  2.399424e+07         15204.633330        21.000000
#
#        NumCreditCard  InterestRate     NumofLoan  Delayfromduedate  \
# count   13744.000000  13744.000000  13744.000000      13744.000000
# mean        5.694558     15.497235      4.018626         22.410434
# std         2.135206      9.014440      2.233565         15.278229
# min         0.000000      1.000000      1.000000         -5.000000
# 25%         4.000000      8.000000      2.000000         11.000000
# 50%         6.000000     15.000000      4.000000         19.000000
# 75%         7.000000     22.000000      6.000000         29.000000
# max        30.000000     88.000000      9.000000         67.000000
#
#        NumofDelayedPayment  ChangedCreditLimit  NumCreditInquiries  \
# count         13744.000000        13744.000000        13744.000000
# mean             13.850844           10.755353            7.736467
# std               6.270563            7.025117            4.023954
# min              -3.000000           -6.400000            0.000000
# 25%               9.000000            5.510000            5.000000
# 50%              14.000000            9.670000            7.000000
# 75%              19.000000           15.490000           11.000000
# max              75.000000           35.810000           26.000000
#
#        OutstandingDebt  CreditUtilizationRatio  TotalEMIpermonth  \
# count     13744.000000            13744.000000      13744.000000
# mean       1542.709957               32.162351       1566.283040
# std        1195.844807                5.053422       8903.991974
# min           0.340000               21.248071          4.462837
# 25%         625.812500               27.999832         43.491959
# 50%        1271.715000               32.186864         83.617233
# 75%        2211.050000               36.313808        181.082179
# max        4998.070000               47.230104      82398.000000
#
#        Amountinvestedmonthly  MonthlyBalance
# count           13744.000000    1.374400e+04
# mean              620.060358   -2.425298e+22
# std              2035.770813    2.843294e+24
# min                 0.000000   -3.333330e+26
# 25%                71.698511    2.634486e+02
# 50%               130.460052    3.224100e+02
# 75%               248.499870    4.457972e+02
# max             10000.000000    1.490361e+03

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# ID                        0
# CustomerID                0
# Month                     0
# Name                      0
# Age                       0
# SSN                       0
# Occupation                0
# AnnualIncome              0
# MonthlyInhandSalary       0
# NumBankAccounts           0
# NumCreditCard             0
# InterestRate              0
# NumofLoan                 0
# TypeofLoan                0
# Delayfromduedate          0
# NumofDelayedPayment       0
# ChangedCreditLimit        0
# NumCreditInquiries        0
# CreditMix                 0
# OutstandingDebt           0
# CreditUtilizationRatio    0
# CreditHistoryAge          0
# PaymentofMinAmount        0
# TotalEMIpermonth          0
# Amountinvestedmonthly     0
# PaymentBehaviour          0
# MonthlyBalance            0
# dtype: int64

# %%
# Display the unique values in each column
print("\nUnique Values in Each Column:")
for column in df.columns:
    print(f"{column}: {df[column].nunique()} unique values")
# Out:
# Unique Values in Each Column:
# ID: 13744 unique values
# CustomerID: 8388 unique values
# Month: 4 unique values
# Name: 7224 unique values
# Age: 44 unique values
# SSN: 8388 unique values
# Occupation: 15 unique values
# AnnualIncome: 8470 unique values
# MonthlyInhandSalary: 8449 unique values
# NumBankAccounts: 13 unique values
# NumCreditCard: 16 unique values
# InterestRate: 34 unique values
# NumofLoan: 9 unique values
# TypeofLoan: 4996 unique values
# Delayfromduedate: 73 unique values
# NumofDelayedPayment: 33 unique values
# ChangedCreditLimit: 2785 unique values
# NumCreditInquiries: 19 unique values
# CreditMix: 3 unique values
# OutstandingDebt: 8273 unique values
# CreditUtilizationRatio: 13744 unique values
# CreditHistoryAge: 399 unique values
# PaymentofMinAmount: 3 unique values
# TotalEMIpermonth: 8770 unique values
# Amountinvestedmonthly: 13102 unique values
# PaymentBehaviour: 6 unique values
# MonthlyBalance: 13744 unique values

# %%
# Display the distribution of categorical columns
print("\nDistribution of Categorical Columns:")
categorical_columns = ['Name', 'Occupation', 'TypeofLoan', 'CreditMix', 'PaymentofMinAmount', 'PaymentBehaviour']
for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].value_counts())
# Out:
# Distribution of Categorical Columns:
#
# Name:
# Name
# Alexei Oreskovics    11
# Jessicad              9
# David Millikenw       9
# N.u                   9
# Leika Kiharal         8
#                      ..
# Leigh Thomasr         1
# Woodallz              1
# Xiaoyi Shaoc          1
# Anno                  1
# Nicks                 1
# Name: count, Length: 7224, dtype: int64
#
# Occupation:
# Occupation
# Lawyer          975
# Architect       963
# Engineer        958
# Accountant      953
# Scientist       949
# Developer       941
# Doctor          935
# Mechanic        924
# Teacher         920
# Entrepreneur    910
# MediaManager    900
# Journalist      874
# Writer          873
# Musician        839
# Manager         830
# Name: count, dtype: int64
#
# TypeofLoan:
# TypeofLoan
# Not Specified                                                                                                                        207
# Debt Consolidation Loan                                                                                                              207
# Credit-Builder Loan                                                                                                                  206
# Personal Loan                                                                                                                        193
# Student Loan                                                                                                                         187
#                                                                                                                                     ...
# Payday Loan, Home Equity Loan, Payday Loan, Home Equity Loan, and Credit-Builder Loan                                                  1
# Payday Loan, Credit-Builder Loan, Student Loan, Mortgage Loan, Credit-Builder Loan, Payday Loan, Personal Loan, and Mortgage Loan      1
# Home Equity Loan, Not Specified, Not Specified, Mortgage Loan, Personal Loan, Auto Loan, and Home Equity Loan                          1
# Auto Loan, Auto Loan, Auto Loan, Auto Loan, Student Loan, and Student Loan                                                             1
# Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan                                                                    1
# Name: count, Length: 4996, dtype: int64
#
# CreditMix:
# CreditMix
# Standard    6239
# Bad         3858
# Good        3647
# Name: count, dtype: int64
#
# PaymentofMinAmount:
# PaymentofMinAmount
# Yes    7802
# No     4246
# NM     1696
# Name: count, dtype: int64
#
# PaymentBehaviour:
# PaymentBehaviour
# LowspentSmallvaluepayments      3758
# HighspentMediumvaluepayments    2586
# LowspentMediumvaluepayments     2086
# HighspentLargevaluepayments     2006
# HighspentSmallvaluepayments     1712
# LowspentLargevaluepayments      1596
# Name: count, dtype: int64

# %%
# Plot histograms for numerical columns
import matplotlib.pyplot as plt

df.hist(bins=20, figsize=(20, 15))
plt.suptitle("Histograms of Numerical Columns")
plt.show()

# %%
# Plot box plots for numerical columns to check for outliers
df.plot(kind='box', subplots=True, layout=(6, 4), figsize=(20, 15), title="Box Plots of Numerical Columns")
plt.show()

# %% [markdown]
# Decision Tree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Convert categorical columns to numerical using one-hot encoding
df = pd.get_dummies(df, drop_first=True)

# %%
# Handling missing values by filling with the median of each column
df.fillna(df.median(), inplace=True)

# %%
# Defining the target variable and features
# Here, we'll assume 'CreditMix_Standard' as the target variable for simplicity
target = 'CreditMix_Standard'
features = df.drop(columns=[target])

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, df[target], test_size=0.3, random_state=42)

# %%
# Training the Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Making predictions
y_pred = clf.predict(X_test)

# %%
# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Print the evaluation metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9740543161978662
# Precision: 0.9696969696969697
# Recall: 0.9742782152230971
# F1 Score: 0.9719821942916994

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Decision Tree - Confusion Matrix')
plt.show()

# %%
##Random Forest Classifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = df.drop(columns=[target])

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, df[target], test_size=0.3, random_state=42)

# %%
# Training the Random Forest Classifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Making predictions
y_pred = clf.predict(X_test)

# %%
# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Print the evaluation metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9791464597478177
# Precision: 0.9814716781365802
# Recall: 0.9732283464566929
# F1 Score: 0.9773326304691619

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Radiant Forest Classifier - Confusion Matrix')
plt.show()

# %%
##Gradiant Boosting Machine (GBMs)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = df.drop(columns=[target])

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, df[target], test_size=0.3, random_state=42)

# %%
# Training the Gradient Boosting Classifier
clf = GradientBoostingClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
# Making predictions
y_pred = clf.predict(X_test)

# %%
# Evaluation Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Print the evaluation metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.972356935014549
# Precision: 0.9651948051948052
# Recall: 0.9753280839895013
# F1 Score: 0.9702349869451697

# %%
# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Gradiant Boosting Machine - Confusion Matrix')
plt.show()
